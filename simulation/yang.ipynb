# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

drill_costs = pd.read_excel("Analysis_Data.xlsx", header=2, sheet_name="Drilling Cost")

drill_costs.head(10)
# Out:
#         Date  \
# 0 1960-06-30
# 1 1961-06-30
# 2 1962-06-30
# 3 1963-06-30
# 4 1964-06-30
# 5 1965-06-30
# 6 1966-06-30
# 7 1967-06-30
# 8 1968-06-30
# 9 1969-06-30
#
#    U.S. Nominal Cost per Crude Oil Well Drilled (Thousand Dollars per Well)  \
# 0                                               52.2
# 1                                               51.3
# 2                                               54.2
# 3                                               51.8
# 4                                               50.6
# 5                                               56.6
# 6                                               62.2
# 7                                               66.6
# 8                                               79.1
# 9                                               86.5
#
#    U.S. Nominal Cost per Natural Gas Well Drilled (Thousand Dollars per Well)  \
# 0                                              102.7
# 1                                               94.7
# 2                                               97.1
# 3                                               92.4
# 4                                              104.8
# 5                                              101.9
# 6                                              133.8
# 7                                              141.0
# 8                                              148.5
# 9                                              154.3
#
#    U.S. Nominal Cost per Dry Well Drilled (Thousand Dollars per Well)  \
# 0                                               44.0
# 1                                               45.2
# 2                                               50.8
# 3                                               48.2
# 4                                               48.5
# 5                                               53.1
# 6                                               56.9
# 7                                               61.5
# 8                                               66.2
# 9                                               70.2
#
#   Arithmetic Return - Crude Oil Arithmetic Return - Natural Gas  \
# 0                             .                               .
# 1                     -0.017241                       -0.077897
# 2                       0.05653                        0.025343
# 3                      -0.04428                       -0.048404
# 4                     -0.023166                        0.134199
# 5                      0.118577                       -0.027672
# 6                       0.09894                        0.313052
# 7                       0.07074                        0.053812
# 8                      0.187688                        0.053191
# 9                      0.093552                        0.039057
#
#   Arithmetic Return - Dry Well
# 0                            .
# 1                     0.027273
# 2                     0.123894
# 3                    -0.051181
# 4                     0.006224
# 5                     0.094845
# 6                     0.071563
# 7                     0.080844
# 8                     0.076423
# 9                     0.060423

# %%
drill_costs = drill_costs[
    (drill_costs["Date"].dt.year >= 1991) & (drill_costs["Date"].dt.year <= 2006)
]
drill_costs
# Out:
#          Date  \
# 31 1991-06-30
# 32 1992-06-30
# 33 1993-06-30
# 34 1994-06-30
# 35 1995-06-30
# 36 1996-06-30
# 37 1997-06-30
# 38 1998-06-30
# 39 1999-06-30
# 40 2000-06-30
# 41 2001-06-30
# 42 2002-06-30
# 43 2003-06-30
# 44 2004-06-30
# 45 2005-06-30
# 46 2006-06-30
#
#     U.S. Nominal Cost per Crude Oil Well Drilled (Thousand Dollars per Well)  \
# 31                                              346.9
# 32                                              362.3
# 33                                              356.6
# 34                                              409.5
# 35                                              415.8
# 36                                              341.0
# 37                                              445.6
# 38                                              566.0
# 39                                              783.0
# 40                                              593.4
# 41                                              729.1
# 42                                              882.8
# 43                                             1037.3
# 44                                             1441.8
# 45                                             1920.4
# 46                                             2238.6
#
#     U.S. Nominal Cost per Natural Gas Well Drilled (Thousand Dollars per Well)  \
# 31                                              506.6
# 32                                              426.1
# 33                                              521.2
# 34                                              535.1
# 35                                              629.7
# 36                                              616.0
# 37                                              728.6
# 38                                              815.6
# 39                                              798.4
# 40                                              756.9
# 41                                              896.5
# 42                                              991.9
# 43                                             1106.0
# 44                                             1716.4
# 45                                             1497.6
# 46                                             1936.2
#
#     U.S. Nominal Cost per Dry Well Drilled (Thousand Dollars per Well)  \
# 31                                              441.2
# 32                                              357.6
# 33                                              387.7
# 34                                              491.5
# 35                                              481.2
# 36                                              541.0
# 37                                              655.6
# 38                                              973.2
# 39                                             1115.5
# 40                                             1075.4
# 41                                             1620.4
# 42                                             1673.4
# 43                                             2065.1
# 44                                             1977.3
# 45                                             2392.9
# 46                                             2664.6
#
#    Arithmetic Return - Crude Oil Arithmetic Return - Natural Gas  \
# 31                      0.077999                        0.074899
# 32                      0.044393                       -0.158902
# 33                     -0.015733                        0.223187
# 34                      0.148345                        0.026669
# 35                      0.015385                        0.176789
# 36                     -0.179894                       -0.021756
# 37                      0.306745                        0.182792
# 38                      0.270197                        0.119407
# 39                      0.383392                       -0.021089
# 40                     -0.242146                       -0.051979
# 41                      0.228682                        0.184437
# 42                      0.210808                        0.106414
# 43                      0.175011                        0.115032
# 44                      0.389955                        0.551899
# 45                      0.331946                       -0.127476
# 46                      0.165695                        0.292869
#
#    Arithmetic Return - Dry Well
# 31                     0.200544
# 32                    -0.189483
# 33                     0.084172
# 34                     0.267733
# 35                    -0.020956
# 36                     0.124273
# 37                      0.21183
# 38                     0.484442
# 39                     0.146219
# 40                    -0.035948
# 41                     0.506788
# 42                     0.032708
# 43                     0.234074
# 44                    -0.042516
# 45                     0.210186
# 46                     0.113544

# %%
returns = drill_costs.filter(regex="^Arithmetic Return").to_numpy().flatten()
drill_costs["avg_cost"] = drill_costs.filter(regex="^U\.S\.").mean(axis=1)
returns, drill_costs["avg_cost"]
# Out:
# (array([0.07799875699192034, 0.0748992149374072, 0.2005442176870748,
#         0.04439319688671097, -0.1589024871693644, -0.18948322756119668,
#         -0.015732818106541507, 0.22318704529453184, 0.08417225950782987,
#         0.14834548513740878, 0.026669224865694504, 0.26773278307970083,
#         0.015384615384615413, 0.17678938516165207, -0.02095625635808751,
#         -0.1798941798941799, -0.02175639193266642, 0.12427265170407317,
#         0.3067448680351907, 0.18279220779220784, 0.21182994454713497,
#         0.2701974865350089, 0.11940708207521274, 0.4844417327638804,
#         0.3833922261484099, -0.021088769004413983, 0.14621866009042328,
#         -0.24214559386973183, -0.05197895791583167, -0.03594800537875384,
#         0.22868217054263573, 0.1844365173734972, 0.5067881718430352,
#         0.21080784528871202, 0.10641383156720577, 0.03270797333991607,
#         0.17501132759401905, 0.11503175723359212, 0.2340743396677422,
#         0.38995469006073463, 0.5518987341772152, -0.042516100915209895,
#         0.33194617838812607, -0.12747611279422055, 0.21018560663531086,
#         0.1656946469485523, 0.29286858974358987, 0.11354423502862628],
#        dtype=object),
#  31     431.566667
#  32     382.000000
#  33     421.833333
#  34     478.700000
#  35     508.900000
#  36     499.333333
#  37     609.933333
#  38     784.933333
#  39     898.966667
#  40     808.566667
#  41    1082.000000
#  42    1182.700000
#  43    1402.800000
#  44    1711.833333
#  45    1936.966667
#  46    2279.800000
#  Name: avg_cost, dtype: float64)

# %%
stats.shapiro(returns)
# Out:
# ShapiroResult(statistic=0.9853200316429138, pvalue=0.8041342496871948)

# %%
rng = np.random.default_rng(1234)
kernel = gaussian_kde(returns)

initial_cost = drill_costs["avg_cost"].iloc[-1]

mean_return = returns.mean()
std_return = returns.std()

years_1 = 2012 - 2006
years_2 = 2015 - 2012
years_3 = 2024 - 2015

kernel.factor
# Out:
# 0.4610539557408639

# %%
norm_data = []
data = []

for i in range(100000):
    normal_return = rng.normal(mean_return, std_return, years_1)
    kernel_return = kernel.resample(years_1).flatten()

    phase_2 = rng.triangular(left=-0.22, mode=-0.0917, right=-0.07, size=years_2)
    phase_3 = rng.triangular(left=0.02, mode=0.05, right=0.06, size=years_3)

    normal_phases = np.concatenate((normal_return, phase_2, phase_3))
    kernel_phases = np.concatenate((kernel_return, phase_2, phase_3))

    normal_future_vals = initial_cost * np.cumprod(1 + normal_phases)
    kernel_future_vals = initial_cost * np.cumprod(1 + kernel_phases)
    norm_data.append(normal_future_vals[-1])
    data.append(kernel_future_vals[-1])

# %%
plt.rcParams.update({"font.size": 12})
plt.hist(norm_data)
plt.axvline(x=np.mean(norm_data), color="r", linestyle="-", linewidth=2)
plt.xlabel("Average Cost")
plt.ylabel("Frequency")
plt.subplots_adjust(left=0.15, right=0.9, top=0.9, bottom=0.15)
plt.savefig("normal_future_vals.png", transparent=True)
plt.show()

# %%
initial_cost
# Out:
# 2279.7999999999997

# %%
np.mean(norm_data)
# Out:
# 4667.951856965687

# %%
np.std(norm_data)
# Out:
# 1866.4921044838127

# %%
np.quantile(norm_data, [0.05, 0.95])
# Out:
# array([2183.24882136, 8144.17801547])

# %%
plt.hist(data)
plt.axvline(x=np.mean(data), color="r", linestyle="-", linewidth=2)
plt.xlabel("Average Cost")
plt.ylabel("Frequency")
plt.savefig("kernel_future_vals.png", transparent=True)
plt.subplots_adjust(left=0.15, right=0.9, top=0.9, bottom=0.15)
plt.tight_layout()
plt.show()

# %%
np.mean(data)
# Out:
# 4659.986398564058
